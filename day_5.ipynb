# %%
class NameThapu(Exception):
    pass
name=input()
if name.isdigit():
    raise NameThapu("Tambi thappu")
print("Tambi right uh")
# Out:
# Tambi right uh

# %%
import logging
try:
    denominator=int(input())
    print(100/denominator)
except Exception:
    logging.exception("Tambi thappu")
finally:
    print("dei Tambi!!")
# Out:
# ERROR:root:Tambi thappu
# Traceback (most recent call last):
#   File "C:\Users\Kaila\AppData\Local\Temp\ipykernel_17500\3166343686.py", line 4, in <module>
#     print(100/denominator)
#           ~~~^~~~~~~~~~~~
# ZeroDivisionError: division by zero
# dei Tambi!!

# %%
def add(a,b):
    return a+b

# %%
def add(a, b):
    return a + b


def test_add(): 
    assert add(4, 5) == 9

# %%
# !pip install pytest
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.1.1, pluggy-1.6.0
# rootdir: c:\Users\Kaila\aerele_practice
# collected 0 items
#
# ============================ no tests ran in 0.01s ============================

# %%
"""import frappe

@frappe.whitelist() # validate autentication and authorization for the current job according to the user
def get_customer(name): #type not mentioned
    result = frappe.db.sql(
        f"SELECT * FROM `tabCustomer` WHERE name='{name}'" #sql injection problem add orm
    )
    print(result) #dont just print. make error handling and logging to maintain correct code ability

    return result  #return in json"""
